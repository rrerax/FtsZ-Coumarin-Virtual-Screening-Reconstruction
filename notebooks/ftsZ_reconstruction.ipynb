# %% [markdown]
# # FtsZ Coumarin HTVS Reconstruction
#
# This notebook loads the cleaned reconstruction outputs and reproduces the summary tables used in the report.

# %%
import pandas as pd
from pathlib import Path
ROOT = Path("..").resolve()
summary = pd.read_csv(ROOT / "results/tables/data_quality_summary.csv")
summary

# %%
top = pd.read_csv(ROOT / "results/tables/top10_unique_structures_by_pocket.csv")
top.groupby("pocket").head(10)

# %%
rerun = pd.read_csv(ROOT / "results/tables/vina_rerun_unique_structures.csv")
rerun

# %%
contacts = pd.read_csv(ROOT / "results/tables/binding_contacts_top_hits.csv")
contacts

# %% [markdown]
# ![Top ligand structures](../results/figures/top_ligand_structures.png)

# %% [markdown]
# ## Binding-mode contact views
#
# PyMOL-style contact views for the best rerun hit from BP1 and BP2. These are docking-pose visualizations, not experimental validation.
#
# ![Binding-mode contact views](../results/figures/binding_mode_top_hits.png)

# %% [markdown]
# ## Figures
#
# ![Score distribution](../results/figures/score_distribution_by_pocket.png)
#
# ![Rerun comparison](../results/figures/vina_rerun_vs_original_scores.png)

# %% [markdown]
# ## EnOpt-style ensemble extension
#
# The extension uses five FtsZ receptor conformations generated by normal-mode perturbation and redocks all 90 cleaned BP1/BP2 unique structures across the ensemble. The weighted score is an exploratory conformation-weighted consensus score, not a supervised activity model.

# %%
enopt_top = pd.read_csv(ROOT / "results/tables/enopt_style_top_hits.csv")
enopt_top

# %%
enopt_weights = pd.read_csv(ROOT / "results/tables/enopt_style_weights.csv")
enopt_weights

# %%
enopt_corr = pd.read_csv(ROOT / "results/tables/enopt_style_correlations.csv")
enopt_corr

# %% [markdown]
# ## EnOpt-style figures
#
# ![EnOpt-style reranking](../results/figures/enopt_style_reranking_vs_legacy.png)
#
# ![Conformation-level score matrix](../results/figures/ensemble_score_matrix_heatmap.png)
#
# ![Conformation weights](../results/figures/enopt_style_conformation_weights.png)
